# %%
import pickle
import time
import numpy as np

max_ngrams = 3 # ngram size
num_generate = 100 # number of passwords to generate

def gen_password(stats, n):
	output = '`' * n
	for i in range(100):
		output += gen_char(output[i:i + n])
		if output[-1] == '\n':
			return output[0:-1].replace('`', '')[0:-1]

def gen_char(ngram):
    if ngram in stats:
        keys = list(stats[ngram].keys())
        values = list(stats[ngram].values())
        return np.random.choice(keys, p=values)
    else:
    	print('{} not in stats dict'.format(ngram))
    	return gen_char(ngram[0:-1])

with open('{}-gram.pickle'.format(max_ngrams),'rb') as file:
	stats = pickle.load(file)

# start = time.time()
f=open('pass.txt','w',encoding='latin-1')
for i in range(num_generate):
    pw = gen_password(stats, max_ngrams)
    f.write(pw)
    f.write("\n")
    if pw is not None:
    	print(pw)
f.close()
# Out:
# krango
# playan
# hae
# el
# 12345
# myhra
# hotpp0722
# texanda326891074
# 61
# jac
# im48
# cooki
# tige
# r2d
# 100
# GUNI
# monke
# ffppros
# lagandr
# *cutez0
# PORT
# mahame
# pturkaboy
# slamaritt
# GARNDO
# guity435478
# bhek
# 1dee0
# win
# YEA
# anins
# sir
# santinatya9
# can
# 091la
# esmarve
# 035070
# 1234
# cham
# dee
# ayja
# qwert
# 3111110
# pare
# PINK0
# mu
# SPIRRISTAR123456789
# salolic
# elle
# masjareshalexanne201183
# aisaarookingbo
# 778
# 24
# viki12345
# rocky3
# 20
# sisto
# dian
# din
# rg4
# e2
# babygir
# jes
# 020011058
# swal
# nurykathyanapsta
# haikay29
# 4y
# 98107070243248
# 58
# therileekyley9
# marcel
# blakomootbolo
# beyo
# jhaj7
# aleofi
# 905j
# head207
# blu
# tai
# jan
# urtle
# can
# iluvchellybird
# matin
# pini
# sams10
# 591
# soft3
# chris2y3m
# loverseskin
# me
# 65
# Kellarrespar
# ge
# 65324
# buffa
# 210809
# poll
# BAN

# %%
import pickle
import time
import numpy as np

max_ngrams = 4 # ngram size
num_generate = 100 # number of passwords to generate

def gen_password(stats, n):
	output = '`' * n
	for i in range(100):
		output += gen_char(output[i:i + n])
		if output[-1] == '\n':
			return output[0:-1].replace('`', '')[0:-1]

def gen_char(ngram):
    if ngram in stats:
        keys = list(stats[ngram].keys())
        values = list(stats[ngram].values())
        return np.random.choice(keys, p=values)
    else:
    	print('{} not in stats dict'.format(ngram))
    	return gen_char(ngram[0:-1])

with open('{}-gram.pickle'.format(max_ngrams),'rb') as file:
	stats = pickle.load(file)

for i in range(num_generate):
	pw = gen_password(stats, max_ngrams)
	if pw is not None:
		print(pw)
# Out:
# assa
# hotti
# 12345
# aedae3n
# july10
# budda9
# kaity
# romeo589
# DESTIA
# 0115
# britne
# ellestimca7
# boobertayma
# hippe
# heathe
# damma
# lis
# pyt32
# carecoo
# nuos2
# rednec
# espat
# 0979Auli\\
# willi
# jessica
# darli
# iluvdav
# gwap
# miga
# nugu
# dnm
# browni
# chatistanyak
# 342
# brandme
# CISNEY3
# anthe
# 19890303
# alycat3
# jess1989198
# mali4
# place
# gisel12
# 4033563
# wel
# edy2690
# liyahah
# thebestbrea
# islamis
# nsan
# heaverdi
# 12345678
# teamoce72
# sandy
# michlan
# gib
# iam
# 3540
# kismin
# kathroo
# triba
# hazen
# 2207
# dre
# eud
# memembe
# alejo
# ashley
# 121
# pelit
# pizza
# asshol
# jfrea
# 123456
# ilove0
# crister36
# turke
# fatbo
# july2
# 880
# o6o9o6o
# nade520197
# 1q2w3e
# snuggle
# PLAYAP
# ronzy
# davi
# jeremiah
# 09197
# roxirock12345
# ho2
# Laurel
# emily1
# missy8
# c572
# 33859denver
# octobe
# dunny
# jan2
# nerik

# %%
import pickle
import time
import numpy as np

max_ngrams = 5 # ngram size
num_generate = 100 # number of passwords to generate

def gen_password(stats, n):
	output = '`' * n
	for i in range(100):
		output += gen_char(output[i:i + n])
		if output[-1] == '\n':
			return output[0:-1].replace('`', '')[0:-1]

def gen_char(ngram):
    if ngram in stats:
		# sample from the probability distribution
        keys = list(stats[ngram].keys())
        values = list(stats[ngram].values())
        return np.random.choice(keys, p=values)
    else:
    	print('{} not in stats dict'.format(ngram))
    	return gen_char(ngram[0:-1])

with open('{}-gram.pickle'.format(max_ngrams),'rb') as file:
	stats = pickle.load(file)

# start = time.time()
f=open('pass.txt','w',encoding='latin-1')
for i in range(num_generate):
    pw = gen_password(stats, max_ngrams)
    f.write(pw)
    f.write("\n")
    if pw is not None:
    	print(pw)
# Out:
# zaq1xsw
# iydvvpo
# 94952
# 1140
# howar
# ilovej
# 12345
# maggi
# 0202
# kawai
# mikecak
# shy on
# rodrigo0
# jaype
# 55555
# what123
# rake_1
# 3344557
# teresa1
# jaylo
# 904068
# yenye
# bogda
# jazel
# LUVE
# lockwoo
#
# 143ysrae
# 121212121
# justi
# cherr
# Ba1141
# pedrit
# lagartinez
# welcom
# 1881
# gatit
# 112991
# nykivia
# lisbo
# 1994cobrali
# maggi
# em30
# keon
# sexsikayna27
# sebasti
# memoI
# 26067
# kiari
# valht81
# jazzy1
# bulal
# dan1
# 1bernia
# jasmin
# jhenche
# butch
# sammyx9
# jasmi
# tiffan
# 1212312
# zachary1
# ilove1
# tina
# coyot
# gatorad
# 747747
# butku
# ZIGGYBAN
# Dipset
# chubb
# 1111111
# raque
# brittnee
# 22039
# precios
# flopp
# 003123
# jacind
# finifilthy
# fluff
# carebea
# jester2
# locaz
# 8014
# carit
# 04228
# 051563
# soccer
# MYroo
# 98765
# 02117
# klees580
# 12345
# lalis
# 0508
# pokemo
# c01080
# lucill
# bubbl

# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in c:\python311\lib\site-packages (42.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\python311\lib\site-packages (from cryptography) (1.15.1)
# Requirement already satisfied: pycparser in c:\python311\lib\site-packages (from cffi>=1.12->cryptography) (2.21)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 23.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
